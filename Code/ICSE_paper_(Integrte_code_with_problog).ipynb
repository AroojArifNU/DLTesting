# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
pip install deepproblog
# Out:
# Collecting deepproblog
#   Downloading deepproblog-2.0.5-py3-none-any.whl (127 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.0/127.0 kB 3.3 MB/s eta 0:00:00
# Collecting pysdd (from deepproblog)
#   Downloading PySDD-0.2.12-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 10.9 MB/s eta 0:00:00
# Collecting problog (from deepproblog)
#   Downloading problog-2.2.4.tar.gz (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 24.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from deepproblog) (2.3.0+cu121)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from deepproblog) (0.18.0+cu121)
# Requirement already satisfied: cython>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from pysdd->deepproblog) (3.0.10)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch->deepproblog) (3.15.3)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch->deepproblog) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->deepproblog) (1.12.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->deepproblog) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->deepproblog) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch->deepproblog) (2023.6.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch->deepproblog)
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch->deepproblog)
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch->deepproblog)
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch->deepproblog)
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch->deepproblog)
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch->deepproblog)
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch->deepproblog)
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch->deepproblog)
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch->deepproblog)
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# Collecting nvidia-nccl-cu12==2.20.5 (from torch->deepproblog)
#   Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch->deepproblog)
#   Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# Requirement already satisfied: triton==2.3.0 in /usr/local/lib/python3.10/dist-packages (from torch->deepproblog) (2.3.0)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch->deepproblog)
#   Downloading nvidia_nvjitlink_cu12-12.5.40-py3-none-manylinux2014_x86_64.whl (21.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.3/21.3 MB 58.1 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torchvision->deepproblog) (1.25.2)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision->deepproblog) (9.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->deepproblog) (2.1.5)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->deepproblog) (1.3.0)
# Building wheels for collected packages: problog
#   Building wheel for problog (setup.py) ... done
#   Created wheel for problog: filename=problog-2.2.4-py3-none-any.whl size=1850662 sha256=3b566356e08b8abae7b8748c6a08257331ab618fc64dff5c02dc1f54edad26f5
#   Stored in directory: /root/.cache/pip/wheels/3b/83/a4/a9ae54a6e59899924bf1552bd5da1038b13ec8d60a22cfa277
# Successfully built problog
# Installing collected packages: problog, pysdd, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, deepproblog
# Successfully installed deepproblog-2.0.5 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.20.5 nvidia-nvjitlink-cu12-12.5.40 nvidia-nvtx-cu12-12.1.105 problog-2.2.4 pysdd-0.2.12

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import load_model
import cv2
from problog.program import PrologString
from problog import get_evaluatable

# Load the MNIST dataset
def load_data(dataset_name='mnist'):
    if dataset_name == 'mnist':
        return mnist.load_data()
    else:
        raise ValueError("Dataset not supported.")

# Preprocess the data
def preprocess_data(x):
    x = x.astype('float32') / 255.0
    x = np.expand_dims(x, -1)
    return x

# Load pre-trained model
def load_trained_model(model_path):
    return load_model(model_path)

# Predict on the test set
def get_predictions(model, x_test):
    predictions = model.predict(x_test)
    predicted_classes = np.argmax(predictions, axis=1)
    return predicted_classes

# Select correctly classified samples
def select_correct_samples(x_test, y_test, predicted_classes, samples_per_class=100):
    correct_samples = {i: [] for i in range(10)}
    for i, (img, label, pred) in enumerate(zip(x_test, y_test, predicted_classes)):
        if label == pred and len(correct_samples[label]) < samples_per_class:
            correct_samples[label].append(img)
        if all(len(correct_samples[l]) == samples_per_class for l in range(10)):
            break
    for label in correct_samples:
        correct_samples[label] = np.array(correct_samples[label])
        print(f"Number of samples for class {label}: {len(correct_samples[label])}")
    return correct_samples

# Define transformation functions
def apply_rotation(image, angle):
    height, width = image.shape[:2]
    center = (width // 2, height // 2)
    rotation_matrix = cv2.getRotationMatrix2D(center, angle, 1.0)
    rotated_image = cv2.warpAffine(image, rotation_matrix, (width, height))
    return rotated_image

def apply_noise(image, noise_factor=0.5):
    noisy_image = image + noise_factor * np.random.randn(*image.shape)
    noisy_image = np.clip(noisy_image, 0., 1.)
    return noisy_image

def apply_brightness(image, brightness_factor=0.5):
    bright_image = image * (1.0 + brightness_factor)
    bright_image = np.clip(bright_image, 0., 1.)
    return bright_image

# Apply transformations to generate test cases
def generate_test_cases(samples):
    rotations = [apply_rotation(img, angle=25) for img in samples]
    noises = [apply_noise(img, noise_factor=0.2) for img in samples]
    brightnesses = [apply_brightness(img, brightness_factor=0.3) for img in samples]
    return rotations, noises, brightnesses

# Generate test cases for each class
def generate_all_transformations(correct_samples):
    all_transformations = {}
    for label in correct_samples:
        rotations, noises, brightnesses = generate_test_cases(correct_samples[label])
        all_transformations[label] = {
            "rotations": rotations,
            "noises": noises,
            "brightnesses": brightnesses
        }
    return all_transformations

# Test model on transformations
def test_model_on_transformations(model, transformations, label):
    accuracies = {}
    for transform_name, transformed_samples in transformations.items():
        transformed_samples = np.array(transformed_samples)
        transformed_samples = transformed_samples.reshape((-1, 28, 28, 1))
        predictions = model.predict(transformed_samples)
        predicted_classes = np.argmax(predictions, axis=1)
        accuracy = np.mean(predicted_classes == np.array([label] * len(transformed_samples)))
        accuracies[transform_name] = accuracy
    return accuracies

# Compute accuracies for each class and each transformation
def compute_class_accuracies(model, all_transformations):
    class_accuracies = {}
    for label, transformations in all_transformations.items():
        accuracies = test_model_on_transformations(model, transformations, label)
        class_accuracies[label] = accuracies
    return class_accuracies

# Generate Problog code based on the accuracies
def generate_problog_code(class_accuracies):
    problog_code = ""
    for label, acc in class_accuracies.items():
        print(f"Class {label} - Noise Accuracy: {acc['noises']}, Brightness Accuracy: {acc['brightnesses']}, Rotation Accuracy: {acc['rotations']}")
        problog_code += f"    {acc['noises']:.6f}::noise_{label}.\n"
        problog_code += f"    {acc['brightnesses']:.6f}::brightness_{label}.\n"
        problog_code += f"    {acc['rotations']:.6f}::rotation_{label}.\n\n"
        problog_code += f"    correct_noise_{label} :- noise_{label}.\n"
        problog_code += f"    correct_brightness_{label} :- brightness_{label}.\n"
        problog_code += f"    correct_rotation_{label} :- rotation_{label}.\n\n"
        problog_code += f"    wrong_noise_{label} :- \\+correct_noise_{label}.\n"
        problog_code += f"    wrong_brightness_{label} :- \\+correct_brightness_{label}.\n"
        problog_code += f"    wrong_rotation_{label} :- \\+correct_rotation_{label}.\n\n"

    # Generating pair rules for all unique pairs (including self-pairs).     # AND Relation
    for i in range(10):
        for j in range(i, 10):
            problog_code += f"    pair_correct_noise_{i}_{j} :- correct_noise_{i}, correct_noise_{j}.\n"
            problog_code += f"    pair_wrong_noise_{i}_{j} :- wrong_noise_{i}, wrong_noise_{j}.\n"
            problog_code += f"    pair_correct_brightness_{i}_{j} :- correct_brightness_{i}, correct_brightness_{j}.\n"
            problog_code += f"    pair_wrong_brightness_{i}_{j} :- wrong_brightness_{i}, wrong_brightness_{j}.\n"
            problog_code += f"    pair_correct_rotation_{i}_{j} :- correct_rotation_{i}, correct_rotation_{j}.\n"
            problog_code += f"    pair_wrong_rotation_{i}_{j} :- wrong_rotation_{i}, wrong_rotation_{j}.\n\n"

    # Generating global correctness rules for each pair.     # OR Relation
    for i in range(10):
        for j in range(i, 10):
            problog_code += f"    global_correct_noise_{i}_{j} :- pair_correct_noise_{i}_{j}; pair_wrong_noise_{i}_{j}.\n"
            problog_code += f"    global_correct_brightness_{i}_{j} :- pair_correct_brightness_{i}_{j}; pair_wrong_brightness_{i}_{j}.\n"
            problog_code += f"    global_correct_rotation_{i}_{j} :- pair_correct_rotation_{i}_{j}; pair_wrong_rotation_{i}_{j}.\n\n"

    # Generating final global correctness rules
    problog_code += "    final_global_correct_noise :- " + ", ".join([f"global_correct_noise_{i}_{j}" for i in range(10) for j in range(i, 10)]) + ".\n"
    problog_code += "    final_global_correct_brightness :- " + ", ".join([f"global_correct_brightness_{i}_{j}" for i in range(10) for j in range(i, 10)]) + ".\n"
    problog_code += "    final_global_correct_rotation :- " + ", ".join([f"global_correct_rotation_{i}_{j}" for i in range(10) for j in range(i, 10)]) + ".\n"

    # Generating the final overall system global correctness rule
    # AND Relation
    # problog_code += "    final_global_correct_system :- final_global_correct_noise, final_global_correct_brightness, final_global_correct_rotation.\n"
    # OR Relation
    problog_code += "    final_global_correct_system :- final_global_correct_noise; final_global_correct_brightness; final_global_correct_rotation.\n"

    # Generating queries
    for i in range(10):
        problog_code += f"query(correct_noise_{i}).\n"
        problog_code += f"query(correct_brightness_{i}).\n"
        problog_code += f"query(correct_rotation_{i}).\n"
        problog_code += f"query(wrong_noise_{i}).\n"
        problog_code += f"query(wrong_brightness_{i}).\n"
        problog_code += f"query(wrong_rotation_{i}).\n"

    for i in range(10):
        for j in range(i, 10):
            problog_code += f"query(pair_correct_noise_{i}_{j}).\n"
            problog_code += f"query(pair_wrong_noise_{i}_{j}).\n"
            problog_code += f"query(pair_correct_brightness_{i}_{j}).\n"
            problog_code += f"query(pair_wrong_brightness_{i}_{j}).\n"
            problog_code += f"query(pair_correct_rotation_{i}_{j}).\n"
            problog_code += f"query(pair_wrong_rotation_{i}_{j}).\n"
            problog_code += f"query(global_correct_noise_{i}_{j}).\n"
            problog_code += f"query(global_correct_brightness_{i}_{j}).\n"
            problog_code += f"query(global_correct_rotation_{i}_{j}).\n"

    problog_code += "query(final_global_correct_noise).\n"
    problog_code += "query(final_global_correct_brightness).\n"
    problog_code += "query(final_global_correct_rotation).\n"
    problog_code += "query(final_global_correct_system).\n"

    return problog_code

# Function to generate Problog code and evaluate it
def evaluate_problog(class_accuracies):
    problog_code = generate_problog_code(class_accuracies)
    prolog_model = PrologString(problog_code)
    result = get_evaluatable().create_from(prolog_model).evaluate()
    return result

# Main function to run the workflow
def main():
    # Step 1: Load the data
    print("Step 1: Loading the data")
    (x_train, y_train), (x_test, y_test) = load_data()
    print("Data loaded successfully")

    # Step 2: Preprocess the data
    print("Step 2: Preprocessing the data")
    x_test = preprocess_data(x_test)
    print("Data preprocessed successfully")

    # Step 3: Load the pre-trained model
    print("Step 3: Loading the pre-trained model")
    model_path = '/content/drive/MyDrive/ColabNotebooks/mnist_model.h5' # Update this path to your model
    model = load_trained_model(model_path)
    print("Model loaded successfully")

    # Step 4: Get predictions
    print("Step 4: Getting predictions on the test set")
    predicted_classes = get_predictions(model, x_test)
    print("Predictions obtained successfully")

    # Step 5: Select correctly classified samples
    print("Step 5: Selecting correctly classified samples")
    correct_samples = select_correct_samples(x_test, y_test, predicted_classes)
    print("Correctly classified samples selected successfully")

    # Step 6: Generate test cases
    print("Step 6: Generating test cases")
    all_transformations = generate_all_transformations(correct_samples)
    print("Test cases generated successfully")

    # Step 7: Compute accuracies for each class and each transformation
    print("Step 7: Computing accuracies for each class and each transformation")
    class_accuracies = compute_class_accuracies(model, all_transformations)
    print("Accuracies computed successfully")

    # Step 8: Generate Problog code and evaluate
    print("Step 8: Generating Problog code and evaluating")
    result = evaluate_problog(class_accuracies)
    print("Problog evaluation result:")
    for query, value in result.items():
        print(f"{query}: {value}")

if __name__ == "__main__":
    main()
# Out:
# Step 1: Loading the data
# Data loaded successfully
# Step 2: Preprocessing the data
# Data preprocessed successfully
# Step 3: Loading the pre-trained model
# Model loaded successfully
# Step 4: Getting predictions on the test set
# 313/313 [==============================] - 3s 9ms/step
# Predictions obtained successfully
# Step 5: Selecting correctly classified samples
# Number of samples for class 0: 100
# Number of samples for class 1: 100
# Number of samples for class 2: 100
# Number of samples for class 3: 100
# Number of samples for class 4: 100
# Number of samples for class 5: 100
# Number of samples for class 6: 100
# Number of samples for class 7: 100
# Number of samples for class 8: 100
# Number of samples for class 9: 100
# Correctly classified samples selected successfully
# Step 6: Generating test cases
# Test cases generated successfully
# Step 7: Computing accuracies for each class and each transformation
# 4/4 [==============================] - 0s 9ms/step
# 4/4 [==============================] - 0s 9ms/step
# 4/4 [==============================] - 0s 8ms/step
# 4/4 [==============================] - 0s 7ms/step
# 4/4 [==============================] - 0s 8ms/step
# 4/4 [==============================] - 0s 7ms/step
# 4/4 [==============================] - 0s 8ms/step
# 4/4 [==============================] - 0s 8ms/step
# 4/4 [==============================] - 0s 8ms/step
# 4/4 [==============================] - 0s 8ms/step
# 4/4 [==============================] - 0s 8ms/step
# 4/4 [==============================] - 0s 8ms/step
# 4/4 [==============================] - 0s 8ms/step
# 4/4 [==============================] - 0s 14ms/step
# 4/4 [==============================] - 0s 9ms/step
# 4/4 [==============================] - 0s 8ms/step
# 4/4 [==============================] - 0s 9ms/step
# 4/4 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 0s 9ms/step
# 4/4 [==============================] - 0s 6ms/step
# 4/4 [==============================] - 0s 7ms/step
# 4/4 [==============================] - 0s 9ms/step
# 4/4 [==============================] - 0s 9ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 6ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 5ms/step
# Accuracies computed successfully
# Step 8: Generating Problog code and evaluating
# Class 0 - Noise Accuracy: 0.79, Brightness Accuracy: 1.0, Rotation Accuracy: 0.99
# Class 1 - Noise Accuracy: 1.0, Brightness Accuracy: 1.0, Rotation Accuracy: 0.99
# Class 2 - Noise Accuracy: 0.8, Brightness Accuracy: 1.0, Rotation Accuracy: 0.76
# Class 3 - Noise Accuracy: 0.77, Brightness Accuracy: 1.0, Rotation Accuracy: 0.82
# Class 4 - Noise Accuracy: 0.89, Brightness Accuracy: 1.0, Rotation Accuracy: 0.91
# Class 5 - Noise Accuracy: 0.99, Brightness Accuracy: 1.0, Rotation Accuracy: 0.89
# Class 6 - Noise Accuracy: 0.61, Brightness Accuracy: 0.99, Rotation Accuracy: 0.87
# Class 7 - Noise Accuracy: 0.87, Brightness Accuracy: 1.0, Rotation Accuracy: 0.75
# Class 8 - Noise Accuracy: 0.06, Brightness Accuracy: 0.99, Rotation Accuracy: 0.68
# Class 9 - Noise Accuracy: 0.44, Brightness Accuracy: 0.99, Rotation Accuracy: 0.93
# Problog evaluation result:
# correct_noise_0: 0.79
# correct_brightness_0: 1.0
# correct_rotation_0: 0.99
# wrong_noise_0: 0.20999999999999996
# wrong_brightness_0: 0.0
# wrong_rotation_0: 0.010000000000000014
# correct_noise_1: 1.0
# correct_brightness_1: 1.0
# correct_rotation_1: 0.99
# wrong_noise_1: 0.0
# wrong_brightness_1: 0.0
# wrong_rotation_1: 0.010000000000000014
# correct_noise_2: 0.8
# correct_brightness_2: 1.0
# correct_rotation_2: 0.76
# wrong_noise_2: 0.19999999999999998
# wrong_brightness_2: 0.0
# wrong_rotation_2: 0.24
# correct_noise_3: 0.77
# correct_brightness_3: 1.0
# correct_rotation_3: 0.82
# wrong_noise_3: 0.23
# wrong_brightness_3: 0.0
# wrong_rotation_3: 0.18000000000000005
# correct_noise_4: 0.89
# correct_brightness_4: 1.0
# correct_rotation_4: 0.91
# wrong_noise_4: 0.10999999999999997
# wrong_brightness_4: 0.0
# wrong_rotation_4: 0.08999999999999998
# correct_noise_5: 0.99
# correct_brightness_5: 1.0
# correct_rotation_5: 0.89
# wrong_noise_5: 0.010000000000000014
# wrong_brightness_5: 0.0
# wrong_rotation_5: 0.10999999999999997
# correct_noise_6: 0.61
# correct_brightness_6: 0.99
# correct_rotation_6: 0.87
# wrong_noise_6: 0.39
# wrong_brightness_6: 0.010000000000000014
# wrong_rotation_6: 0.13
# correct_noise_7: 0.87
# correct_brightness_7: 1.0
# correct_rotation_7: 0.75
# wrong_noise_7: 0.13
# wrong_brightness_7: 0.0
# wrong_rotation_7: 0.25
# correct_noise_8: 0.06
# correct_brightness_8: 0.99
# correct_rotation_8: 0.68
# wrong_noise_8: 0.9400000000000001
# wrong_brightness_8: 0.010000000000000014
# wrong_rotation_8: 0.31999999999999995
# correct_noise_9: 0.44
# correct_brightness_9: 0.99
# correct_rotation_9: 0.93
# wrong_noise_9: 0.5599999999999999
# wrong_brightness_9: 0.010000000000000014
# wrong_rotation_9: 0.06999999999999995
# pair_correct_noise_0_0: 0.79
# pair_wrong_noise_0_0: 0.20999999999999996
# pair_correct_brightness_0_0: 1.0
# pair_wrong_brightness_0_0: 0.0
# pair_correct_rotation_0_0: 0.99
# pair_wrong_rotation_0_0: 0.010000000000000014
# global_correct_noise_0_0: 1.0
# global_correct_brightness_0_0: 1.0
# global_correct_rotation_0_0: 1.0
# pair_correct_noise_0_1: 0.79
# pair_wrong_noise_0_1: 0.0
# pair_correct_brightness_0_1: 1.0
# pair_wrong_brightness_0_1: 0.0
# pair_correct_rotation_0_1: 0.9801
# pair_wrong_rotation_0_1: 0.00010000000000000026
# global_correct_noise_0_1: 0.79
# global_correct_brightness_0_1: 1.0
# global_correct_rotation_0_1: 0.9802
# pair_correct_noise_0_2: 0.6320000000000001
# pair_wrong_noise_0_2: 0.041999999999999996
# pair_correct_brightness_0_2: 1.0
# pair_wrong_brightness_0_2: 0.0
# pair_correct_rotation_0_2: 0.7524
# pair_wrong_rotation_0_2: 0.0024000000000000037
# global_correct_noise_0_2: 0.674
# global_correct_brightness_0_2: 1.0
# global_correct_rotation_0_2: 0.7548
# pair_correct_noise_0_3: 0.6083000000000001
# pair_wrong_noise_0_3: 0.04829999999999998
# pair_correct_brightness_0_3: 1.0
# pair_wrong_brightness_0_3: 0.0
# pair_correct_rotation_0_3: 0.8118
# pair_wrong_rotation_0_3: 0.001800000000000003
# global_correct_noise_0_3: 0.6566000000000001
# global_correct_brightness_0_3: 1.0
# global_correct_rotation_0_3: 0.8136
# pair_correct_noise_0_4: 0.7031000000000001
# pair_wrong_noise_0_4: 0.023099999999999992
# pair_correct_brightness_0_4: 1.0
# pair_wrong_brightness_0_4: 0.0
# pair_correct_rotation_0_4: 0.9009
# pair_wrong_rotation_0_4: 0.0009000000000000014
# global_correct_noise_0_4: 0.7262000000000001
# global_correct_brightness_0_4: 1.0
# global_correct_rotation_0_4: 0.9018
# pair_correct_noise_0_5: 0.7821
# pair_wrong_noise_0_5: 0.002100000000000003
# pair_correct_brightness_0_5: 1.0
# pair_wrong_brightness_0_5: 0.0
# pair_correct_rotation_0_5: 0.8811
# pair_wrong_rotation_0_5: 0.0011000000000000012
# global_correct_noise_0_5: 0.7842000000000001
# global_correct_brightness_0_5: 1.0
# global_correct_rotation_0_5: 0.8822000000000001
# pair_correct_noise_0_6: 0.4819
# pair_wrong_noise_0_6: 0.08189999999999999
# pair_correct_brightness_0_6: 0.99
# pair_wrong_brightness_0_6: 0.0
# pair_correct_rotation_0_6: 0.8613
# pair_wrong_rotation_0_6: 0.0013000000000000017
# global_correct_noise_0_6: 0.5638
# global_correct_brightness_0_6: 0.99
# global_correct_rotation_0_6: 0.8626
# pair_correct_noise_0_7: 0.6873
# pair_wrong_noise_0_7: 0.0273
# pair_correct_brightness_0_7: 1.0
# pair_wrong_brightness_0_7: 0.0
# pair_correct_rotation_0_7: 0.7424999999999999
# pair_wrong_rotation_0_7: 0.002500000000000003
# global_correct_noise_0_7: 0.7146
# global_correct_brightness_0_7: 1.0
# global_correct_rotation_0_7: 0.745
# pair_correct_noise_0_8: 0.0474
# pair_wrong_noise_0_8: 0.19739999999999994
# pair_correct_brightness_0_8: 0.99
# pair_wrong_brightness_0_8: 0.0
# pair_correct_rotation_0_8: 0.6732
# pair_wrong_rotation_0_8: 0.0032000000000000045
# global_correct_noise_0_8: 0.24479999999999993
# global_correct_brightness_0_8: 0.99
# global_correct_rotation_0_8: 0.6764
# pair_correct_noise_0_9: 0.3476
# pair_wrong_noise_0_9: 0.1176
# pair_correct_brightness_0_9: 0.99
# pair_wrong_brightness_0_9: 0.0
# pair_correct_rotation_0_9: 0.9207000000000001
# pair_wrong_rotation_0_9: 0.0007000000000000008
# global_correct_noise_0_9: 0.46520000000000006
# global_correct_brightness_0_9: 0.99
# global_correct_rotation_0_9: 0.9214
# pair_correct_noise_1_1: 1.0
# pair_wrong_noise_1_1: 0.0
# pair_correct_brightness_1_1: 1.0
# pair_wrong_brightness_1_1: 0.0
# pair_correct_rotation_1_1: 0.99
# pair_wrong_rotation_1_1: 0.010000000000000014
# global_correct_noise_1_1: 1.0
# global_correct_brightness_1_1: 1.0
# global_correct_rotation_1_1: 1.0
# pair_correct_noise_1_2: 0.8
# pair_wrong_noise_1_2: 0.0
# pair_correct_brightness_1_2: 1.0
# pair_wrong_brightness_1_2: 0.0
# pair_correct_rotation_1_2: 0.7524
# pair_wrong_rotation_1_2: 0.0024000000000000037
# global_correct_noise_1_2: 0.8
# global_correct_brightness_1_2: 1.0
# global_correct_rotation_1_2: 0.7548
# pair_correct_noise_1_3: 0.77
# pair_wrong_noise_1_3: 0.0
# pair_correct_brightness_1_3: 1.0
# pair_wrong_brightness_1_3: 0.0
# pair_correct_rotation_1_3: 0.8118
# pair_wrong_rotation_1_3: 0.001800000000000003
# global_correct_noise_1_3: 0.77
# global_correct_brightness_1_3: 1.0
# global_correct_rotation_1_3: 0.8136
# pair_correct_noise_1_4: 0.89
# pair_wrong_noise_1_4: 0.0
# pair_correct_brightness_1_4: 1.0
# pair_wrong_brightness_1_4: 0.0
# pair_correct_rotation_1_4: 0.9009
# pair_wrong_rotation_1_4: 0.0009000000000000014
# global_correct_noise_1_4: 0.89
# global_correct_brightness_1_4: 1.0
# global_correct_rotation_1_4: 0.9018
# pair_correct_noise_1_5: 0.99
# pair_wrong_noise_1_5: 0.0
# pair_correct_brightness_1_5: 1.0
# pair_wrong_brightness_1_5: 0.0
# pair_correct_rotation_1_5: 0.8811
# pair_wrong_rotation_1_5: 0.0011000000000000012
# global_correct_noise_1_5: 0.99
# global_correct_brightness_1_5: 1.0
# global_correct_rotation_1_5: 0.8822000000000001
# pair_correct_noise_1_6: 0.61
# pair_wrong_noise_1_6: 0.0
# pair_correct_brightness_1_6: 0.99
# pair_wrong_brightness_1_6: 0.0
# pair_correct_rotation_1_6: 0.8613
# pair_wrong_rotation_1_6: 0.0013000000000000017
# global_correct_noise_1_6: 0.61
# global_correct_brightness_1_6: 0.99
# global_correct_rotation_1_6: 0.8626
# pair_correct_noise_1_7: 0.87
# pair_wrong_noise_1_7: 0.0
# pair_correct_brightness_1_7: 1.0
# pair_wrong_brightness_1_7: 0.0
# pair_correct_rotation_1_7: 0.7424999999999999
# pair_wrong_rotation_1_7: 0.002500000000000003
# global_correct_noise_1_7: 0.87
# global_correct_brightness_1_7: 1.0
# global_correct_rotation_1_7: 0.745
# pair_correct_noise_1_8: 0.06
# pair_wrong_noise_1_8: 0.0
# pair_correct_brightness_1_8: 0.99
# pair_wrong_brightness_1_8: 0.0
# pair_correct_rotation_1_8: 0.6732
# pair_wrong_rotation_1_8: 0.0032000000000000045
# global_correct_noise_1_8: 0.06
# global_correct_brightness_1_8: 0.99
# global_correct_rotation_1_8: 0.6764
# pair_correct_noise_1_9: 0.44
# pair_wrong_noise_1_9: 0.0
# pair_correct_brightness_1_9: 0.99
# pair_wrong_brightness_1_9: 0.0
# pair_correct_rotation_1_9: 0.9207000000000001
# pair_wrong_rotation_1_9: 0.0007000000000000008
# global_correct_noise_1_9: 0.44
# global_correct_brightness_1_9: 0.99
# global_correct_rotation_1_9: 0.9214
# pair_correct_noise_2_2: 0.8
# pair_wrong_noise_2_2: 0.19999999999999998
# pair_correct_brightness_2_2: 1.0
# pair_wrong_brightness_2_2: 0.0
# pair_correct_rotation_2_2: 0.76
# pair_wrong_rotation_2_2: 0.24
# global_correct_noise_2_2: 1.0
# global_correct_brightness_2_2: 1.0
# global_correct_rotation_2_2: 1.0
# pair_correct_noise_2_3: 0.616
# pair_wrong_noise_2_3: 0.04599999999999999
# pair_correct_brightness_2_3: 1.0
# pair_wrong_brightness_2_3: 0.0
# pair_correct_rotation_2_3: 0.6232
# pair_wrong_rotation_2_3: 0.043200000000000016
# global_correct_noise_2_3: 0.662
# global_correct_brightness_2_3: 1.0
# global_correct_rotation_2_3: 0.6664
# pair_correct_noise_2_4: 0.7120000000000001
# pair_wrong_noise_2_4: 0.021999999999999992
# pair_correct_brightness_2_4: 1.0
# pair_wrong_brightness_2_4: 0.0
# pair_correct_rotation_2_4: 0.6916
# pair_wrong_rotation_2_4: 0.021599999999999987
# global_correct_noise_2_4: 0.734
# global_correct_brightness_2_4: 1.0
# global_correct_rotation_2_4: 0.7132000000000001
# pair_correct_noise_2_5: 0.792
# pair_wrong_noise_2_5: 0.002000000000000002
# pair_correct_brightness_2_5: 1.0
# pair_wrong_brightness_2_5: 0.0
# pair_correct_rotation_2_5: 0.6764
# pair_wrong_rotation_2_5: 0.026399999999999996
# global_correct_noise_2_5: 0.794
# global_correct_brightness_2_5: 1.0
# global_correct_rotation_2_5: 0.7028
# pair_correct_noise_2_6: 0.48800000000000004
# pair_wrong_noise_2_6: 0.07800000000000001
# pair_correct_brightness_2_6: 0.99
# pair_wrong_brightness_2_6: 0.0
# pair_correct_rotation_2_6: 0.6612
# pair_wrong_rotation_2_6: 0.031200000000000006
# global_correct_noise_2_6: 0.5660000000000001
# global_correct_brightness_2_6: 0.99
# global_correct_rotation_2_6: 0.6924
# pair_correct_noise_2_7: 0.6960000000000001
# pair_wrong_noise_2_7: 0.025999999999999995
# pair_correct_brightness_2_7: 1.0
# pair_wrong_brightness_2_7: 0.0
# pair_correct_rotation_2_7: 0.57
# pair_wrong_rotation_2_7: 0.06
# global_correct_noise_2_7: 0.722
# global_correct_brightness_2_7: 1.0
# global_correct_rotation_2_7: 0.63
# pair_correct_noise_2_8: 0.048
# pair_wrong_noise_2_8: 0.18799999999999997
# pair_correct_brightness_2_8: 0.99
# pair_wrong_brightness_2_8: 0.0
# pair_correct_rotation_2_8: 0.5168
# pair_wrong_rotation_2_8: 0.07679999999999998
# global_correct_noise_2_8: 0.23599999999999996
# global_correct_brightness_2_8: 0.99
# global_correct_rotation_2_8: 0.5936
# pair_correct_noise_2_9: 0.352
# pair_wrong_noise_2_9: 0.11199999999999999
# pair_correct_brightness_2_9: 0.99
# pair_wrong_brightness_2_9: 0.0
# pair_correct_rotation_2_9: 0.7068000000000001
# pair_wrong_rotation_2_9: 0.01679999999999998
# global_correct_noise_2_9: 0.46399999999999997
# global_correct_brightness_2_9: 0.99
# global_correct_rotation_2_9: 0.7236
# pair_correct_noise_3_3: 0.77
# pair_wrong_noise_3_3: 0.23
# pair_correct_brightness_3_3: 1.0
# pair_wrong_brightness_3_3: 0.0
# pair_correct_rotation_3_3: 0.82
# pair_wrong_rotation_3_3: 0.18000000000000005
# global_correct_noise_3_3: 1.0
# global_correct_brightness_3_3: 1.0
# global_correct_rotation_3_3: 1.0
# pair_correct_noise_3_4: 0.6853
# pair_wrong_noise_3_4: 0.025299999999999993
# pair_correct_brightness_3_4: 1.0
# pair_wrong_brightness_3_4: 0.0
# pair_correct_rotation_3_4: 0.7462
# pair_wrong_rotation_3_4: 0.016200000000000006
# global_correct_noise_3_4: 0.7106
# global_correct_brightness_3_4: 1.0
# global_correct_rotation_3_4: 0.7624
# pair_correct_noise_3_5: 0.7623
# pair_wrong_noise_3_5: 0.002300000000000002
# pair_correct_brightness_3_5: 1.0
# pair_wrong_brightness_3_5: 0.0
# pair_correct_rotation_3_5: 0.7298
# pair_wrong_rotation_3_5: 0.019799999999999998
# global_correct_noise_3_5: 0.7646000000000001
# global_correct_brightness_3_5: 1.0
# global_correct_rotation_3_5: 0.7496
# pair_correct_noise_3_6: 0.4697
# pair_wrong_noise_3_6: 0.08969999999999999
# pair_correct_brightness_3_6: 0.99
# pair_wrong_brightness_3_6: 0.0
# pair_correct_rotation_3_6: 0.7133999999999999
# pair_wrong_rotation_3_6: 0.023400000000000008
# global_correct_noise_3_6: 0.5594
# global_correct_brightness_3_6: 0.99
# global_correct_rotation_3_6: 0.7368
# pair_correct_noise_3_7: 0.6699
# pair_wrong_noise_3_7: 0.0299
# pair_correct_brightness_3_7: 1.0
# pair_wrong_brightness_3_7: 0.0
# pair_correct_rotation_3_7: 0.615
# pair_wrong_rotation_3_7: 0.045000000000000005
# global_correct_noise_3_7: 0.6998
# global_correct_brightness_3_7: 1.0
# global_correct_rotation_3_7: 0.6599999999999999
# pair_correct_noise_3_8: 0.04619999999999999
# pair_wrong_noise_3_8: 0.21619999999999998
# pair_correct_brightness_3_8: 0.99
# pair_wrong_brightness_3_8: 0.0
# pair_correct_rotation_3_8: 0.5576
# pair_wrong_rotation_3_8: 0.05760000000000002
# global_correct_noise_3_8: 0.26239999999999997
# global_correct_brightness_3_8: 0.99
# global_correct_rotation_3_8: 0.6152000000000001
# pair_correct_noise_3_9: 0.3388
# pair_wrong_noise_3_9: 0.1288
# pair_correct_brightness_3_9: 0.99
# pair_wrong_brightness_3_9: 0.0
# pair_correct_rotation_3_9: 0.7626
# pair_wrong_rotation_3_9: 0.0126
# global_correct_noise_3_9: 0.4676
# global_correct_brightness_3_9: 0.99
# global_correct_rotation_3_9: 0.7752
# pair_correct_noise_4_4: 0.89
# pair_wrong_noise_4_4: 0.10999999999999997
# pair_correct_brightness_4_4: 1.0
# pair_wrong_brightness_4_4: 0.0
# pair_correct_rotation_4_4: 0.91
# pair_wrong_rotation_4_4: 0.08999999999999998
# global_correct_noise_4_4: 1.0
# global_correct_brightness_4_4: 1.0
# global_correct_rotation_4_4: 1.0
# pair_correct_noise_4_5: 0.8811
# pair_wrong_noise_4_5: 0.0011000000000000012
# pair_correct_brightness_4_5: 1.0
# pair_wrong_brightness_4_5: 0.0
# pair_correct_rotation_4_5: 0.8099000000000001
# pair_wrong_rotation_4_5: 0.009899999999999999
# global_correct_noise_4_5: 0.8822000000000001
# global_correct_brightness_4_5: 1.0
# global_correct_rotation_4_5: 0.8198000000000001
# pair_correct_noise_4_6: 0.5429
# pair_wrong_noise_4_6: 0.0429
# pair_correct_brightness_4_6: 0.99
# pair_wrong_brightness_4_6: 0.0
# pair_correct_rotation_4_6: 0.7917000000000001
# pair_wrong_rotation_4_6: 0.011699999999999992
# global_correct_noise_4_6: 0.5858
# global_correct_brightness_4_6: 0.99
# global_correct_rotation_4_6: 0.8034
# pair_correct_noise_4_7: 0.7743
# pair_wrong_noise_4_7: 0.014299999999999995
# pair_correct_brightness_4_7: 1.0
# pair_wrong_brightness_4_7: 0.0
# pair_correct_rotation_4_7: 0.6825
# pair_wrong_rotation_4_7: 0.0225
# global_correct_noise_4_7: 0.7886000000000001
# global_correct_brightness_4_7: 1.0
# global_correct_rotation_4_7: 0.7050000000000001
# pair_correct_noise_4_8: 0.05339999999999999
# pair_wrong_noise_4_8: 0.10339999999999996
# pair_correct_brightness_4_8: 0.99
# pair_wrong_brightness_4_8: 0.0
# pair_correct_rotation_4_8: 0.6188000000000001
# pair_wrong_rotation_4_8: 0.02879999999999998
# global_correct_noise_4_8: 0.15679999999999994
# global_correct_brightness_4_8: 0.99
# global_correct_rotation_4_8: 0.6476000000000001
# pair_correct_noise_4_9: 0.3916
# pair_wrong_noise_4_9: 0.06159999999999998
# pair_correct_brightness_4_9: 0.99
# pair_wrong_brightness_4_9: 0.0
# pair_correct_rotation_4_9: 0.8463
# pair_wrong_rotation_4_9: 0.006299999999999994
# global_correct_noise_4_9: 0.4532
# global_correct_brightness_4_9: 0.99
# global_correct_rotation_4_9: 0.8526
# pair_correct_noise_5_5: 0.99
# pair_wrong_noise_5_5: 0.010000000000000014
# pair_correct_brightness_5_5: 1.0
# pair_wrong_brightness_5_5: 0.0
# pair_correct_rotation_5_5: 0.89
# pair_wrong_rotation_5_5: 0.10999999999999997
# global_correct_noise_5_5: 1.0
# global_correct_brightness_5_5: 1.0
# global_correct_rotation_5_5: 1.0
# pair_correct_noise_5_6: 0.6039
# pair_wrong_noise_5_6: 0.0039000000000000063
# pair_correct_brightness_5_6: 0.99
# pair_wrong_brightness_5_6: 0.0
# pair_correct_rotation_5_6: 0.7743
# pair_wrong_rotation_5_6: 0.014299999999999995
# global_correct_noise_5_6: 0.6078
# global_correct_brightness_5_6: 0.99
# global_correct_rotation_5_6: 0.7886000000000001
# pair_correct_noise_5_7: 0.8613
# pair_wrong_noise_5_7: 0.0013000000000000017
# pair_correct_brightness_5_7: 1.0
# pair_wrong_brightness_5_7: 0.0
# pair_correct_rotation_5_7: 0.6675
# pair_wrong_rotation_5_7: 0.027499999999999986
# global_correct_noise_5_7: 0.8626
# global_correct_brightness_5_7: 1.0
# global_correct_rotation_5_7: 0.695
# pair_correct_noise_5_8: 0.05939999999999999
# pair_wrong_noise_5_8: 0.009400000000000016
# pair_correct_brightness_5_8: 0.99
# pair_wrong_brightness_5_8: 0.0
# pair_correct_rotation_5_8: 0.6052000000000001
# pair_wrong_rotation_5_8: 0.03519999999999999
# global_correct_noise_5_8: 0.06879999999999999
# global_correct_brightness_5_8: 0.99
# global_correct_rotation_5_8: 0.6404000000000001
# pair_correct_noise_5_9: 0.4356
# pair_wrong_noise_5_9: 0.005600000000000008
# pair_correct_brightness_5_9: 0.99
# pair_wrong_brightness_5_9: 0.0
# pair_correct_rotation_5_9: 0.8277
# pair_wrong_rotation_5_9: 0.007699999999999995
# global_correct_noise_5_9: 0.4412
# global_correct_brightness_5_9: 0.99
# global_correct_rotation_5_9: 0.8354
# pair_correct_noise_6_6: 0.61
# pair_wrong_noise_6_6: 0.39
# pair_correct_brightness_6_6: 0.99
# pair_wrong_brightness_6_6: 0.010000000000000014
# pair_correct_rotation_6_6: 0.87
# pair_wrong_rotation_6_6: 0.13
# global_correct_noise_6_6: 1.0
# global_correct_brightness_6_6: 1.0
# global_correct_rotation_6_6: 1.0
# pair_correct_noise_6_7: 0.5307
# pair_wrong_noise_6_7: 0.050700000000000016
# pair_correct_brightness_6_7: 0.99
# pair_wrong_brightness_6_7: 0.0
# pair_correct_rotation_6_7: 0.6525
# pair_wrong_rotation_6_7: 0.032499999999999994
# global_correct_noise_6_7: 0.5814
# global_correct_brightness_6_7: 0.99
# global_correct_rotation_6_7: 0.6849999999999999
# pair_correct_noise_6_8: 0.0366
# pair_wrong_noise_6_8: 0.36660000000000004
# pair_correct_brightness_6_8: 0.9801
# pair_wrong_brightness_6_8: 0.00010000000000000026
# pair_correct_rotation_6_8: 0.5916
# pair_wrong_rotation_6_8: 0.0416
# global_correct_noise_6_8: 0.4032
# global_correct_brightness_6_8: 0.9802
# global_correct_rotation_6_8: 0.6332000000000001
# pair_correct_noise_6_9: 0.26839999999999997
# pair_wrong_noise_6_9: 0.2184
# pair_correct_brightness_6_9: 0.9801
# pair_wrong_brightness_6_9: 0.00010000000000000026
# pair_correct_rotation_6_9: 0.8091
# pair_wrong_rotation_6_9: 0.00909999999999999
# global_correct_noise_6_9: 0.4868
# global_correct_brightness_6_9: 0.9802
# global_correct_rotation_6_9: 0.8182
# pair_correct_noise_7_7: 0.87
# pair_wrong_noise_7_7: 0.13
# pair_correct_brightness_7_7: 1.0
# pair_wrong_brightness_7_7: 0.0
# pair_correct_rotation_7_7: 0.75
# pair_wrong_rotation_7_7: 0.25
# global_correct_noise_7_7: 1.0
# global_correct_brightness_7_7: 1.0
# global_correct_rotation_7_7: 1.0
# pair_correct_noise_7_8: 0.052199999999999996
# pair_wrong_noise_7_8: 0.12219999999999999
# pair_correct_brightness_7_8: 0.99
# pair_wrong_brightness_7_8: 0.0
# pair_correct_rotation_7_8: 0.51
# pair_wrong_rotation_7_8: 0.07999999999999999
# global_correct_noise_7_8: 0.17439999999999997
# global_correct_brightness_7_8: 0.99
# global_correct_rotation_7_8: 0.5900000000000001
# pair_correct_noise_7_9: 0.3828
# pair_wrong_noise_7_9: 0.0728
# pair_correct_brightness_7_9: 0.99
# pair_wrong_brightness_7_9: 0.0
# pair_correct_rotation_7_9: 0.6975
# pair_wrong_rotation_7_9: 0.01749999999999999
# global_correct_noise_7_9: 0.45559999999999995
# global_correct_brightness_7_9: 0.99
# global_correct_rotation_7_9: 0.7150000000000001
# pair_correct_noise_8_8: 0.06
# pair_wrong_noise_8_8: 0.9400000000000001
# pair_correct_brightness_8_8: 0.99
# pair_wrong_brightness_8_8: 0.010000000000000014
# pair_correct_rotation_8_8: 0.68
# pair_wrong_rotation_8_8: 0.31999999999999995
# global_correct_noise_8_8: 1.0
# global_correct_brightness_8_8: 1.0
# global_correct_rotation_8_8: 1.0
# pair_correct_noise_8_9: 0.026399999999999996
# pair_wrong_noise_8_9: 0.5264
# pair_correct_brightness_8_9: 0.9801
# pair_wrong_brightness_8_9: 0.00010000000000000026
# pair_correct_rotation_8_9: 0.6324000000000001
# pair_wrong_rotation_8_9: 0.022399999999999975
# global_correct_noise_8_9: 0.5528000000000001
# global_correct_brightness_8_9: 0.9802
# global_correct_rotation_8_9: 0.6548
# pair_correct_noise_9_9: 0.44
# pair_wrong_noise_9_9: 0.5599999999999999
# pair_correct_brightness_9_9: 0.99
# pair_wrong_brightness_9_9: 0.010000000000000014
# pair_correct_rotation_9_9: 0.93
# pair_wrong_rotation_9_9: 0.06999999999999995
# global_correct_noise_9_9: 1.0
# global_correct_brightness_9_9: 1.0
# global_correct_rotation_9_9: 1.0
# final_global_correct_noise: 0.00600739265472192
# final_global_correct_brightness: 0.970299
# final_global_correct_rotation: 0.20412754393430602
# final_global_correct_system: 0.9765037961784073
